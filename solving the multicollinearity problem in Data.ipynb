# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Consider the dataset 'weatherAUS' called Rain in Australia. It describes the weather characteristics on different dates and locations. This dataset contains about 10 years of daily weather observations from many locations across Australia

# %%
df = pd.read_csv(r"C:\Users\tbala\OneDrive\Desktop\Academics\DataSets\weatherAUS.csv")
# link for Dataset
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# ## 6. Preprocess the data, remove the attributes which were are not useful to predict rain. Also, remove rows with at least one missing value for each of them.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df = df.dropna()    # removed the rows with atleast one missing value
df.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 6054  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 6049         SSW           48.0        ENE  ...        20.0         13.0
# 6050           S           37.0        SSE  ...        30.0          8.0
# 6052         NNE           46.0        NNE  ...        42.0         22.0
# 6053         WNW           31.0        WNW  ...        37.0         22.0
# 6054         WNW           35.0         NW  ...        19.0         15.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.749687  0.110800     0.506764  0.076087
# MaxTemp        0.749687  1.000000 -0.069981     0.650964  0.463913
# Rainfall       0.110800 -0.069981  1.000000    -0.077239 -0.246379
# Evaporation    0.506764  0.650964 -0.077239     1.000000  0.369250
# Sunshine       0.076087  0.463913 -0.246379     0.369250  1.000000
# WindGustSpeed  0.118054  0.035531  0.106308     0.209566 -0.052422
# WindSpeed9am   0.108522 -0.008171  0.050584     0.193154 -0.013842
# WindSpeed3pm   0.137273  0.012266  0.044112     0.124345  0.029200
# Humidity9am   -0.174991 -0.495781  0.263625    -0.554232 -0.500343
# Humidity3pm    0.070827 -0.448116  0.277625    -0.422436 -0.629299
# Pressure9am   -0.475661 -0.350980 -0.180606    -0.297319  0.043330
# Pressure3pm   -0.495577 -0.451691 -0.137302    -0.325954 -0.020632
# Cloud9am       0.106177 -0.263634  0.217169    -0.199809 -0.677939
# ...

# %%
df.head(2)
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 6049         SSW           48.0        ENE  ...        20.0         13.0
# 6050           S           37.0        SSE  ...        30.0          8.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 6049       1006.3       1004.4       2.0       5.0     26.6     33.4
# 6050       1012.9       1012.1       1.0       1.0     20.3     27.0
#
#       RainToday  RainTomorrow
# 6049         No            No
# 6050         No            No
#
# [2 rows x 23 columns]

# %%
df.drop('Date',axis = 1,inplace = True)
df.head(2)
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6049    Cobar     17.9     35.2       0.0         12.0      12.3         SSW
# 6050    Cobar     18.4     28.9       0.0         14.8      13.0           S
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 6049           48.0        ENE         SW  ...         20.0         13.0
# 6050           37.0        SSE        SSE  ...         30.0          8.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 6049       1006.3       1004.4       2.0       5.0     26.6     33.4
# 6050       1012.9       1012.1       1.0       1.0     20.3     27.0
#
#       RainToday  RainTomorrow
# 6049         No            No
# 6050         No            No
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Date is not usefull in prediction

# %%
df.Location.value_counts()
# Out:
# Darwin              3062
# Perth               3025
# Brisbane            2953
# MelbourneAirport    2929
# PerthAirport        2913
# SydneyAirport       2870
# Watsonia            2730
# Mildura             2594
# MountGambier        2465
# NorfolkIsland       2464
# Cairns              2444
# Townsville          2419
# WaggaWagga          2416
# AliceSprings        2223
# Nuriootpa           2008
# Hobart              1939
# Moree               1913
# Melbourne           1898
# Portland            1863
# Woomera             1734
# Sydney              1690
# Sale                1678
# CoffsHarbour        1380
# Williamtown         1198
# Canberra            1078
# Cobar                534
# Name: Location, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head(2)
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6049    Cobar     17.9     35.2       0.0         12.0      12.3         SSW
# 6050    Cobar     18.4     28.9       0.0         14.8      13.0           S
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 6049           48.0        ENE         SW  ...         20.0         13.0
# 6050           37.0        SSE        SSE  ...         30.0          8.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 6049       1006.3       1004.4       2.0       5.0     26.6     33.4
# 6050       1012.9       1012.1       1.0       1.0     20.3     27.0
#
#       RainToday  RainTomorrow
# 6049         No            No
# 6050         No            No
#
# [2 rows x 22 columns]

# %%
# categorical varables may have importance in the analysis
le_windgustdir = LabelEncoder()
le_WindDir9am = LabelEncoder()
le_WindDir3pm = LabelEncoder()
le_RainToday = LabelEncoder()
le_RainTomorrow = LabelEncoder()
le_Location = LabelEncoder()

# %%
df['le_windgustdir'] = le_windgustdir.fit_transform(df.WindGustDir)
df['le_WindDir9am'] = le_windgustdir.fit_transform(df.WindDir9am)
df['le_WindDir3pm'] = le_windgustdir.fit_transform(df.WindDir3pm)
df['le_RainToday'] = le_windgustdir.fit_transform(df.RainToday)
df['le_RainTomorrow'] = le_windgustdir.fit_transform(df.RainTomorrow)
df['le_Location'] = le_windgustdir.fit_transform(df.Location)

# %%
df.head(2)
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6049    Cobar     17.9     35.2       0.0         12.0      12.3         SSW
# 6050    Cobar     18.4     28.9       0.0         14.8      13.0           S
#
#       WindGustSpeed WindDir9am WindDir3pm  ...  Temp9am  Temp3pm  RainToday  \
# 6049           48.0        ENE         SW  ...     26.6     33.4         No
# 6050           37.0        SSE        SSE  ...     20.3     27.0         No
#
#       RainTomorrow  le_windgustdir  le_WindDir9am  le_WindDir3pm  \
# 6049            No              11              1             12
# 6050            No               8             10             10
#
#       le_RainToday  le_RainTomorrow  le_Location
# 6049             0                0            4
# 6050             0                0            4
#
# [2 rows x 28 columns]

# %%
df.drop(['Location','WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow'],axis = 1,inplace = True)
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Cloud9am  \
# 6049           6.0          20.0         20.0         13.0  ...       2.0
# 6050          19.0          19.0         30.0          8.0  ...       1.0
# 6052          30.0          15.0         42.0         22.0  ...       1.0
# 6053           6.0           6.0         37.0         22.0  ...       1.0
# 6054          17.0          13.0         19.0         15.0  ...       1.0
#
#       Cloud3pm  Temp9am  Temp3pm  le_windgustdir  le_WindDir9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MinTemp          56420 non-null  float64
#  1   MaxTemp          56420 non-null  float64
#  2   Rainfall         56420 non-null  float64
#  3   Evaporation      56420 non-null  float64
#  4   Sunshine         56420 non-null  float64
#  5   WindGustSpeed    56420 non-null  float64
#  6   WindSpeed9am     56420 non-null  float64
#  7   WindSpeed3pm     56420 non-null  float64
#  8   Humidity9am      56420 non-null  float64
#  9   Humidity3pm      56420 non-null  float64
#  10  Pressure9am      56420 non-null  float64
#  11  Pressure3pm      56420 non-null  float64
#  12  Cloud9am         56420 non-null  float64
#  13  Cloud3pm         56420 non-null  float64
#  14  Temp9am          56420 non-null  float64
#  15  Temp3pm          56420 non-null  float64
# ...

# %%
corr = df.corr()
corr
# Out:
#                   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp          1.000000  0.749687  0.110800     0.506764  0.076087
# MaxTemp          0.749687  1.000000 -0.069981     0.650964  0.463913
# Rainfall         0.110800 -0.069981  1.000000    -0.077239 -0.246379
# Evaporation      0.506764  0.650964 -0.077239     1.000000  0.369250
# Sunshine         0.076087  0.463913 -0.246379     0.369250  1.000000
# WindGustSpeed    0.118054  0.035531  0.106308     0.209566 -0.052422
# WindSpeed9am     0.108522 -0.008171  0.050584     0.193154 -0.013842
# WindSpeed3pm     0.137273  0.012266  0.044112     0.124345  0.029200
# Humidity9am     -0.174991 -0.495781  0.263625    -0.554232 -0.500343
# Humidity3pm      0.070827 -0.448116  0.277625    -0.422436 -0.629299
# Pressure9am     -0.475661 -0.350980 -0.180606    -0.297319  0.043330
# Pressure3pm     -0.495577 -0.451691 -0.137302    -0.325954 -0.020632
# Cloud9am         0.106177 -0.263634  0.217169    -0.199809 -0.677939
# ...

# %%
corr['le_RainTomorrow'].abs().sort_values(ascending=False)

# the attrbutes which are more relevant for the prediction of rainfall are listed below
# Out:
# le_RainTomorrow    1.000000
# Humidity3pm        0.455358
# Sunshine           0.453407
# Cloud3pm           0.388574
# Cloud9am           0.323972
# le_RainToday       0.309098
# Humidity9am        0.271033
# Pressure9am        0.254816
# Rainfall           0.254342
# WindGustSpeed      0.233158
# Pressure3pm        0.230418
# Temp3pm            0.183586
# MaxTemp            0.147467
# Evaporation        0.130002
# WindSpeed3pm       0.088862
# MinTemp            0.087428
# WindSpeed9am       0.083904
# le_windgustdir     0.061751
# le_WindDir9am      0.035992
# le_WindDir3pm      0.032203
# Temp9am            0.018179
# le_Location        0.005100
# Name: le_RainTomorrow, dtype: float64

# %%
# after Evaporation all attributes has less correlation
df = df.drop(['le_windgustdir','le_WindDir9am','le_WindDir3pm'],axis = 1)

# above droped attributes are irrelevant for our prediction

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6049           6.0          20.0         20.0         13.0       1006.3
# 6050          19.0          19.0         30.0          8.0       1012.9
# 6052          30.0          15.0         42.0         22.0       1012.3
# 6053           6.0           6.0         37.0         22.0       1012.7
# 6054          17.0          13.0         19.0         15.0       1010.7
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  le_RainToday  \
# ...

# %% [markdown]
# ## 7. Calculate the Variance Inflation Factor (VIF) value. VIF is a number that determines whether a variable has multicollinearity or not (starts from 1, and it has no upper limit. If the number gets larger, it means the variable has huge multicollinearity on it.).

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
x = df.drop('le_RainTomorrow',axis =1)
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns  

vif_data["VIF"] = [variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
  
print(vif_data)
# Out:
#           feature            VIF
# 0         MinTemp      58.284344
# 1         MaxTemp     610.084145
# 2        Rainfall       1.631133
# 3     Evaporation       7.309774
# 4        Sunshine      17.321181
# 5   WindGustSpeed      26.979473
# 6    WindSpeed9am       8.403994
# 7    WindSpeed3pm      13.874266
# 8     Humidity9am      61.247296
# 9     Humidity3pm      47.945481
# 10    Pressure9am  435850.404023
# 11    Pressure3pm  434065.443559
# 12       Cloud9am       7.365545
# 13       Cloud3pm       8.323980
# 14        Temp9am     213.833301
# 15        Temp3pm     675.404916
# 16   le_RainToday       2.228824
# 17    le_Location       4.405711

# %% [markdown]
# ## 8. Remove multicollinearities by creating new features. Find the features that have paired values and create the new feature which is the difference value between those pairs.

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6049           6.0          20.0         20.0         13.0       1006.3
# 6050          19.0          19.0         30.0          8.0       1012.9
# 6052          30.0          15.0         42.0         22.0       1012.3
# 6053           6.0           6.0         37.0         22.0       1012.7
# 6054          17.0          13.0         19.0         15.0       1010.7
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  le_RainToday  \
# ...

# %%
df['TempDiff'] = df['Temp3pm'] - df['Temp9am']
df['HumidityDiff'] = df['Humidity3pm'] - df['Humidity9am']
df['CloudDiff'] = df['Cloud3pm'] - df['Cloud9am']
df['WindSpeedDiff'] = df['WindSpeed3pm'] - df['WindSpeed9am']
df['PressureDiff'] = df['Pressure3pm'] - df['Pressure9am']

new_df = df.drop(['Temp3pm', 'Temp9am', 'Humidity3pm', 'Humidity9am', 'Cloud3pm', 'Cloud9am', 'WindSpeed3pm', 'WindSpeed9am', 'Pressure3pm', 'Pressure9am'], axis=1)

new_df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       le_RainToday  le_RainTomorrow  le_Location  TempDiff  HumidityDiff  \
# 6049             0                0            4       6.8          -7.0
# 6050             0                0            4       6.7         -22.0
# 6052             0                0            4       6.2         -20.0
# 6053             0                0            4       6.5         -15.0
# 6054             0                0            4       4.0          -4.0
#
#       CloudDiff  WindSpeedDiff  PressureDiff
# 6049        3.0           14.0          -1.9
# ...

# %%
vif_info = pd.DataFrame()
X = new_df.drop('le_RainTomorrow',axis =1)
vif_info['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_info['Column'] = X.columns
vif_info.sort_values('VIF', ascending=False)
# Out:
#           VIF         Column
# 1   91.994450        MaxTemp
# 0   35.706987        MinTemp
# 8   14.370612       TempDiff
# 4    9.025333       Sunshine
# 5    8.619098  WindGustSpeed
# 3    6.126678    Evaporation
# 9    5.641793   HumidityDiff
# 12   3.842925   PressureDiff
# 7    3.717848    le_Location
# 6    2.132534   le_RainToday
# 2    1.604418       Rainfall
# 11   1.375730  WindSpeedDiff
# 10   1.082939      CloudDiff

# %% [markdown]
# ## 9. Remove features that have a VIF value above 5.

# %%
new_df = new_df.drop(['MaxTemp','MinTemp','TempDiff','WindGustSpeed','Sunshine'],axis =1)

# %%
new_df.head(2)
# Out:
#       Rainfall  Evaporation  le_RainToday  le_RainTomorrow  le_Location  \
# 6049       0.0         12.0             0                0            4
# 6050       0.0         14.8             0                0            4
#
#       HumidityDiff  CloudDiff  WindSpeedDiff  PressureDiff
# 6049          -7.0        3.0           14.0          -1.9
# 6050         -22.0        0.0            0.0          -0.8

# %%
vif_info = pd.DataFrame()
X = new_df.drop('le_RainTomorrow',axis =1)
vif_info['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_info['Column'] = X.columns
vif_info.sort_values('VIF', ascending=False)
# Out:
#         VIF         Column
# 3  2.877981    le_Location
# 1  2.503369    Evaporation
# 7  2.428761   PressureDiff
# 4  2.121856   HumidityDiff
# 2  1.806084   le_RainToday
# 0  1.576039       Rainfall
# 6  1.227352  WindSpeedDiff
# 5  1.020719      CloudDiff

# %% [markdown]
# ## 10.Build a regression model to perform the Rain prediction. Also, tabulate accuracy of the prediction models, before and VIF computation.

# %%
new_df.head()
# Out:
#       Rainfall  Evaporation  le_RainToday  le_RainTomorrow  le_Location  \
# 6049       0.0         12.0             0                0            4
# 6050       0.0         14.8             0                0            4
# 6052       0.0         10.8             0                0            4
# 6053       0.0         11.4             0                0            4
# 6054       0.0         11.2             0                0            4
#
#       HumidityDiff  CloudDiff  WindSpeedDiff  PressureDiff
# 6049          -7.0        3.0           14.0          -1.9
# 6050         -22.0        0.0            0.0          -0.8
# 6052         -20.0        5.0          -15.0          -3.1
# 6053         -15.0        4.0            0.0          -3.6
# 6054          -4.0        5.0           -4.0          -3.3

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Temp9am  \
# 6049           6.0          20.0         20.0         13.0  ...     26.6
# 6050          19.0          19.0         30.0          8.0  ...     20.3
# 6052          30.0          15.0         42.0         22.0  ...     28.7
# 6053           6.0           6.0         37.0         22.0  ...     29.1
# 6054          17.0          13.0         19.0         15.0  ...     33.6
#
#       Temp3pm  le_RainToday  le_RainTomorrow  le_Location  TempDiff  \
# ...

# %% [markdown]
# # After computing of vif

# %%
inputs_new = new_df.drop('le_RainTomorrow',axis = 1)
target_new = new_df.le_RainTomorrow

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs_new,target_new,test_size = 0.3)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8106463429044074

# %%
new_df.head(2)
# Out:
#       Rainfall  Evaporation  le_RainToday  le_RainTomorrow  le_Location  \
# 6049       0.0         12.0             0                0            4
# 6050       0.0         14.8             0                0            4
#
#       HumidityDiff  CloudDiff  WindSpeedDiff  PressureDiff
# 6049          -7.0        3.0           14.0          -1.9
# 6050         -22.0        0.0            0.0          -0.8

# %%
X_test.head(2)
# Out:
#        Rainfall  Evaporation  le_RainToday  le_Location  HumidityDiff  \
# 32618       0.2          4.0             0           19         -16.0
# 32182       0.0          6.0             0           19           4.0
#
#        CloudDiff  WindSpeedDiff  PressureDiff
# 32618       -2.0            6.0          -0.8
# 32182        4.0            3.0          -2.1

# %%
y_pred = model.predict(X_test)

# %%
y_test
# Out:
# 32618     0
# 32182     1
# 75005     0
# 35098     0
# 68997     0
#          ..
# 120459    0
# 104241    0
# 46474     1
# 84368     0
# 89621     1
# Name: le_RainTomorrow, Length: 16926, dtype: int32

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot = True)
# Out:
# <AxesSubplot:>

# %%
print(cm)
# Out:
# [[12596   589]
#  [ 2616  1125]]

# %% [markdown]
# # before computing of vif

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Temp9am  \
# 6049           6.0          20.0         20.0         13.0  ...     26.6
# 6050          19.0          19.0         30.0          8.0  ...     20.3
# 6052          30.0          15.0         42.0         22.0  ...     28.7
# 6053           6.0           6.0         37.0         22.0  ...     29.1
# 6054          17.0          13.0         19.0         15.0  ...     33.6
#
#       Temp3pm  le_RainToday  le_RainTomorrow  le_Location  TempDiff  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MinTemp          56420 non-null  float64
#  1   MaxTemp          56420 non-null  float64
#  2   Rainfall         56420 non-null  float64
#  3   Evaporation      56420 non-null  float64
#  4   Sunshine         56420 non-null  float64
#  5   WindGustSpeed    56420 non-null  float64
#  6   WindSpeed9am     56420 non-null  float64
#  7   WindSpeed3pm     56420 non-null  float64
#  8   Humidity9am      56420 non-null  float64
#  9   Humidity3pm      56420 non-null  float64
#  10  Pressure9am      56420 non-null  float64
#  11  Pressure3pm      56420 non-null  float64
#  12  Cloud9am         56420 non-null  float64
#  13  Cloud3pm         56420 non-null  float64
#  14  Temp9am          56420 non-null  float64
#  15  Temp3pm          56420 non-null  float64
# ...

# %%
df = df.drop(['TempDiff','HumidityDiff','CloudDiff','WindSpeedDiff','PressureDiff'],axis = 1)
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 6049     17.9     35.2       0.0         12.0      12.3           48.0
# 6050     18.4     28.9       0.0         14.8      13.0           37.0
# 6052     19.4     37.6       0.0         10.8      10.6           46.0
# 6053     21.9     38.4       0.0         11.4      12.2           31.0
# 6054     24.2     41.0       0.0         11.2       8.4           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 6049           6.0          20.0         20.0         13.0       1006.3
# 6050          19.0          19.0         30.0          8.0       1012.9
# 6052          30.0          15.0         42.0         22.0       1012.3
# 6053           6.0           6.0         37.0         22.0       1012.7
# 6054          17.0          13.0         19.0         15.0       1010.7
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  le_RainToday  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MinTemp          56420 non-null  float64
#  1   MaxTemp          56420 non-null  float64
#  2   Rainfall         56420 non-null  float64
#  3   Evaporation      56420 non-null  float64
#  4   Sunshine         56420 non-null  float64
#  5   WindGustSpeed    56420 non-null  float64
#  6   WindSpeed9am     56420 non-null  float64
#  7   WindSpeed3pm     56420 non-null  float64
#  8   Humidity9am      56420 non-null  float64
#  9   Humidity3pm      56420 non-null  float64
#  10  Pressure9am      56420 non-null  float64
#  11  Pressure3pm      56420 non-null  float64
#  12  Cloud9am         56420 non-null  float64
#  13  Cloud3pm         56420 non-null  float64
#  14  Temp9am          56420 non-null  float64
#  15  Temp3pm          56420 non-null  float64
# ...

# %%
inputs = df.drop('le_RainTomorrow',axis = 1)
target = df.le_RainTomorrow

# %%
model_before_vif = LogisticRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size = 0.3)

# %%
model_before_vif.fit(X_train,y_train)
# Out:
# C:\Users\tbala\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_before_vif.score(X_test,y_test)
# Out:
# 0.8538934184095475
